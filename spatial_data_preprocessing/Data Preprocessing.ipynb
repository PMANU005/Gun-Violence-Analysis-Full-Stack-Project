# %%
#Cleaning DataSet1

# %%
import pandas as pd
#Reading dataset1 from csv
df1 = pd.read_csv('dataset1.csv')
df1.head()
# Out:
#          Date                      City State   Latitude   Longitude  \
# 0  2009-01-27                Wilmington    CA  33.783263 -118.254934
# 1  2009-02-14                 Brockport    NY  43.221000  -77.943000
# 2  2009-03-05                 Cleveland    OH  41.477464  -81.686514
# 3  2009-03-10  Coffee and Geneva County    AL  31.112900  -86.045900
# 4  2009-03-15                     Miami    FL  25.737781  -80.259580
#
#    Total shot  Number killed  Number wounded  \
# 0           6              6               0
# 1           5              4               1
# 2           6              5               1
# 3          14             10               4
# 4           4              4               0
#
#   Assault weapon OR high-capacity magazine Prohibited shooter  \
# 0                                       No                 No
# 1                                       No                 No
# 2                                       No                Yes
# 3                                      Yes                 No
# 4                                      Yes                 No
#
#   Killed intimate partner or family Dangerous warning signs  \
# 0                               Yes                      No
# 1                                No                     Yes
# 2                               Yes                      No
# 3                               Yes                      No
# 4                               Yes                      No
#
#                                            Narrative              Last updated
# 0  A shooter fatally shot his wife and their five...  2021-06-02T14:41:58.000Z
# 1  A shooter fatally shot a nurse in the parking ...  2021-06-02T14:41:58.000Z
# 2  A shooter fatally shot his wife and four of he...  2021-06-02T14:41:58.000Z
# 3  A shooter killed 10 people and injured four in...  2021-06-02T14:41:58.000Z
# 4  At a birthday party, a shooter fatally shot hi...  2021-06-02T14:41:58.000Z

# %%
#Inorder to convert two letter state abbrevation to full name stored those mapping in dictionary 
us_state_to_abbrev = {
"Alabama": "AL","Alaska": "AK","Arizona": "AZ","Arkansas": "AR","California": "CA","Colorado": "CO", "Connecticut": "CT","Delaware": "DE","Florida": "FL","Georgia": "GA","Hawaii": "HI","Idaho": "ID","Illinois": "IL","Indiana": "IN","Iowa": "IA","Kansas": "KS", "Kentucky": "KY","Louisiana": "LA",
"Maine": "ME","Maryland": "MD","Massachusetts": "MA", "Michigan": "MI", "Minnesota": "MN","Mississippi": "MS","Missouri": "MO","Montana": "MT", "Nebraska": "NE","Nevada": "NV","New Hampshire": "NH", "New Jersey": "NJ","New Mexico": "NM","New York": "NY","North Carolina": "NC","North Dakota": "ND","Ohio": "OH","Oklahoma": "OK","Oregon": "OR","Pennsylvania": "PA", "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))

# %%
#Converted two leter short cut state name into full name.
df1['State'] = df1['State'].map(lambda x: abbrev_to_us_state.get(x, x))
#Took desired columns from the whole dataset
final_df1 =df1[['Date', 'City' , 'State' , 'Latitude' , 'Longitude']]
#Dropping rows with missing values
final_df1.dropna()
# Out:
#            Date                      City           State   Latitude  \
# 0    2009-01-27                Wilmington      California  33.783263
# 1    2009-02-14                 Brockport        New York  43.221000
# 2    2009-03-05                 Cleveland            Ohio  41.477464
# 3    2009-03-10  Coffee and Geneva County         Alabama  31.112900
# 4    2009-03-15                     Miami         Florida  25.737781
# ..          ...                       ...             ...        ...
# 279  2022-08-05           Butler Township            Ohio  39.850517
# 280  2022-09-09                 Elk Mills        Maryland  36.661673
# 281  2022-09-29                  McGregor           Texas  31.443668
# 282  2022-10-05                     Inman  South Carolina  35.047452
# 283  2022-10-14                   Raleigh  North Carolina  35.809129
#
#       Longitude
# 0   -118.254934
# 1    -77.943000
# 2    -81.686514
# 3    -86.045900
# 4    -80.259580
# ..          ...
# 279  -84.216189
# 280  -75.836240
# 281  -97.409259
# 282  -82.092965
# 283  -78.547613
#
# [284 rows x 5 columns]

# %%
final_df1
# Out:
#            Date                      City           State   Latitude  \
# 0    2009-01-27                Wilmington      California  33.783263
# 1    2009-02-14                 Brockport        New York  43.221000
# 2    2009-03-05                 Cleveland            Ohio  41.477464
# 3    2009-03-10  Coffee and Geneva County         Alabama  31.112900
# 4    2009-03-15                     Miami         Florida  25.737781
# ..          ...                       ...             ...        ...
# 279  2022-08-05           Butler Township            Ohio  39.850517
# 280  2022-09-09                 Elk Mills        Maryland  36.661673
# 281  2022-09-29                  McGregor           Texas  31.443668
# 282  2022-10-05                     Inman  South Carolina  35.047452
# 283  2022-10-14                   Raleigh  North Carolina  35.809129
#
#       Longitude
# 0   -118.254934
# 1    -77.943000
# 2    -81.686514
# 3    -86.045900
# 4    -80.259580
# ..          ...
# 279  -84.216189
# 280  -75.836240
# 281  -97.409259
# 282  -82.092965
# 283  -78.547613
#
# [284 rows x 5 columns]

# %%
#Cleaning DataSet2

# %%
#Reading datase2 from csv
df2 = pd.read_csv('dataset2.csv')
#Renaming columns
df2.rename(columns = {'Incident Date':'Date', 'City Or County':'City'}, inplace = True)
df2.head()
# Out:
#    Incident ID               Date      State         City  \
# 0      2458602  November 12, 2022    Florida      Orlando
# 1      2458584  November 12, 2022  Minnesota  Minneapolis
# 2      2458282  November 12, 2022    Alabama       Dothan
# 3      2458349  November 12, 2022  Tennessee      Madison
# 4      2458426  November 12, 2022   Kentucky    Lexington
#
#                         Address  # Killed  # Injured  Operations
# 0            801 Rio Grande Ave         1          2         NaN
# 1   4700 block of Lyndale Ave N         1          0         NaN
# 2      W Main St and Montana St         1          1         NaN
# 3  Maple St and Gallatin Pike S         1          1         NaN
# 4   300 block of Darby Creek Rd         1          0         NaN

# %%
#Extracting exact address by merging the coolumns 
df2['CompAddress']=df2['Address']+", "+df2['City']+", "+df2['State']+", USA"
df2['PartialAddress']=df2['City']+", "+df2['State']+", USA"

# %%
#Converting date to "YYY-MM-DD" format
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2.head()
# Out:
#    Incident ID       Date      State         City  \
# 0      2458602 2022-11-12    Florida      Orlando
# 1      2458584 2022-11-12  Minnesota  Minneapolis
# 2      2458282 2022-11-12    Alabama       Dothan
# 3      2458349 2022-11-12  Tennessee      Madison
# 4      2458426 2022-11-12   Kentucky    Lexington
#
#                         Address  # Killed  # Injured  Operations  \
# 0            801 Rio Grande Ave         1          2         NaN
# 1   4700 block of Lyndale Ave N         1          0         NaN
# 2      W Main St and Montana St         1          1         NaN
# 3  Maple St and Gallatin Pike S         1          1         NaN
# 4   300 block of Darby Creek Rd         1          0         NaN
#
#                                          CompAddress  \
# 0          801 Rio Grande Ave, Orlando, Florida, USA
# 1  4700 block of Lyndale Ave N, Minneapolis, Minn...
# 2     W Main St and Montana St, Dothan, Alabama, USA
# 3  Maple St and Gallatin Pike S, Madison, Tenness...
# 4  300 block of Darby Creek Rd, Lexington, Kentuc...
#
#                 PartialAddress
# 0        Orlando, Florida, USA
# 1  Minneapolis, Minnesota, USA
# 2         Dothan, Alabama, USA
# 3      Madison, Tennessee, USA
# 4     Lexington, Kentucky, USA

# %%
#Extracting required columns for geocoding
finaldata2=df2[['Date', 'City' , 'State' , 'CompAddress','PartialAddress']]
finaldata2.dropna()
# Out:
#            Date          City         State  \
# 0    2022-11-12       Orlando       Florida
# 1    2022-11-12   Minneapolis     Minnesota
# 2    2022-11-12        Dothan       Alabama
# 3    2022-11-12       Madison     Tennessee
# 4    2022-11-12     Lexington      Kentucky
# ...         ...           ...           ...
# 1995 2022-09-29       Memphis     Tennessee
# 1996 2022-09-29  Mount Vernon      Illinois
# 1997 2022-09-29       Modesto    California
# 1998 2022-09-29    Youngstown          Ohio
# 1999 2022-09-29  Philadelphia  Pennsylvania
#
#                                             CompAddress  \
# 0             801 Rio Grande Ave, Orlando, Florida, USA
# 1     4700 block of Lyndale Ave N, Minneapolis, Minn...
# 2        W Main St and Montana St, Dothan, Alabama, USA
# 3     Maple St and Gallatin Pike S, Madison, Tenness...
# 4     300 block of Darby Creek Rd, Lexington, Kentuc...
# ...                                                 ...
# 1995                  Bryan St, Memphis, Tennessee, USA
# 1996         16584 N IL-37, Mount Vernon, Illinois, USA
# 1997  Mitchell Rd and S Riverside Dr, Modesto, Calif...
# 1998  New York Ave and Logan Ave, Youngstown, Ohio, USA
# 1999     1105 S 54th S, Philadelphia, Pennsylvania, USA
#
#                        PartialAddress
# 0               Orlando, Florida, USA
# 1         Minneapolis, Minnesota, USA
# 2                Dothan, Alabama, USA
# 3             Madison, Tennessee, USA
# 4            Lexington, Kentucky, USA
# ...                               ...
# 1995          Memphis, Tennessee, USA
# 1996      Mount Vernon, Illinois, USA
# 1997         Modesto, California, USA
# 1998            Youngstown, Ohio, USA
# 1999  Philadelphia, Pennsylvania, USA
#
# [1964 rows x 5 columns]

# %%
finaldata2
# Out:
#            Date          City         State  \
# 0    2022-11-12       Orlando       Florida
# 1    2022-11-12   Minneapolis     Minnesota
# 2    2022-11-12        Dothan       Alabama
# 3    2022-11-12       Madison     Tennessee
# 4    2022-11-12     Lexington      Kentucky
# ...         ...           ...           ...
# 1995 2022-09-29       Memphis     Tennessee
# 1996 2022-09-29  Mount Vernon      Illinois
# 1997 2022-09-29       Modesto    California
# 1998 2022-09-29    Youngstown          Ohio
# 1999 2022-09-29  Philadelphia  Pennsylvania
#
#                                             CompAddress  \
# 0             801 Rio Grande Ave, Orlando, Florida, USA
# 1     4700 block of Lyndale Ave N, Minneapolis, Minn...
# 2        W Main St and Montana St, Dothan, Alabama, USA
# 3     Maple St and Gallatin Pike S, Madison, Tenness...
# 4     300 block of Darby Creek Rd, Lexington, Kentuc...
# ...                                                 ...
# 1995                  Bryan St, Memphis, Tennessee, USA
# 1996         16584 N IL-37, Mount Vernon, Illinois, USA
# 1997  Mitchell Rd and S Riverside Dr, Modesto, Calif...
# 1998  New York Ave and Logan Ave, Youngstown, Ohio, USA
# 1999     1105 S 54th S, Philadelphia, Pennsylvania, USA
#
#                        PartialAddress
# 0               Orlando, Florida, USA
# 1         Minneapolis, Minnesota, USA
# 2                Dothan, Alabama, USA
# 3             Madison, Tennessee, USA
# 4            Lexington, Kentucky, USA
# ...                               ...
# 1995          Memphis, Tennessee, USA
# 1996      Mount Vernon, Illinois, USA
# 1997         Modesto, California, USA
# 1998            Youngstown, Ohio, USA
# 1999  Philadelphia, Pennsylvania, USA
#
# [2000 rows x 5 columns]

# %%
#downloading finaldata2 to local using google sheets to use geocode api and to get corresponding latitude and longitutudes for given address
finaldata2.to_csv('finaldata2.csv')

# %%
#After gecoding in googlesheets downloaded the "finaldata2 - finaldata2.csv" to local file and read the file from local

# %%
finaldata2 = pd.read_csv('finaldata2 - finaldata2.csv')

# %%
#In this database weh have latitude and longitude
finaldata2.head()
# Out:
#    Unnamed: 0        Date         City      State  \
# 0           1  2022-11-12      Orlando    Florida
# 1           2  2022-11-12  Minneapolis  Minnesota
# 2           3  2022-11-12       Dothan    Alabama
# 3           4  2022-11-12      Madison  Tennessee
# 4           5  2022-11-12    Lexington   Kentucky
#
#                                          CompAddress   Latitude  Longitude  \
# 0          801 Rio Grande Ave, Orlando, Florida, USA  28.533346 -81.399993
# 1  4700 block of Lyndale Ave N, Minneapolis, Minn...  45.041023 -93.286121
# 2     W Main St and Montana St, Dothan, Alabama, USA  31.225759 -85.402452
# 3  Maple St and Gallatin Pike S, Madison, Tenness...  36.248822 -86.719791
# 4  300 block of Darby Creek Rd, Lexington, Kentuc...  38.003982 -84.433147
#
#                 PartialAddress
# 0        Orlando, Florida, USA
# 1  Minneapolis, Minnesota, USA
# 2         Dothan, Alabama, USA
# 3      Madison, Tennessee, USA
# 4     Lexington, Kentucky, USA

# %%
#Cleaning dataset3

# %%
#Reading dataset from local
df3 = pd.read_csv('datset3-b8243c3bcdfe.csv')
df3.head()
# Out:
#    Incident ID      Incident Date                 State  \
# 0      2457100  November 10, 2022              Maryland
# 1      2457053  November 10, 2022              Colorado
# 2      2457065  November 10, 2022  District of Columbia
# 3      2456538   November 9, 2022         Massachusetts
# 4      2456391   November 9, 2022              Virginia
#
#            City Or County                          Address  # Killed  \
# 0  Hyattsville (Landover)         7200 block of E Ridge Dr         1
# 1                  Pueblo          3600 block of Dillon Dr         1
# 2              Washington  Pomeroy Rd SE and Stanton Rd SE         1
# 3                  Boston         Paxton St and Harvard St         1
# 4                  Oakton    11400 block of Waples Mill Rd         1
#
#    # Injured  Operations
# 0          0         NaN
# 1          0         NaN
# 2          0         NaN
# 3          0         NaN
# 4          0         NaN

# %%
df3.rename(columns = {'Incident Date':'Date', 'City Or County':'City'}, inplace = True)
df3['CompAddress']=df3['Address']+", "+df3['City']+", "+df3['State']+", USA"
df3['Date'] = pd.to_datetime(df3['Date'])
#Dropping rows whose adress column as na values.
df3=df3.dropna(subset=['Address'])
finaldata3=df3[['Date', 'City' , 'State' , 'CompAddress']]
finaldata3.head()
# Out:
#         Date                    City                 State  \
# 0 2022-11-10  Hyattsville (Landover)              Maryland
# 1 2022-11-10                  Pueblo              Colorado
# 2 2022-11-10              Washington  District of Columbia
# 3 2022-11-09                  Boston         Massachusetts
# 4 2022-11-09                  Oakton              Virginia
#
#                                          CompAddress
# 0  7200 block of E Ridge Dr, Hyattsville (Landove...
# 1     3600 block of Dillon Dr, Pueblo, Colorado, USA
# 2  Pomeroy Rd SE and Stanton Rd SE, Washington, D...
# 3  Paxton St and Harvard St, Boston, Massachusett...
# 4  11400 block of Waples Mill Rd, Oakton, Virgini...

# %%
#downloading finaldata3 to local using google sheets to use geocode api and to get corresponding latitude and longitutudes for given address
finaldata3.to_csv('finaldata3.csv')

# %%
#After gecoding in googlesheets downloaded the "finaldata2 - finaldata2.csv" to local file and read the file from local
finaldata3=pd.read_csv('finaldata3 - finaldata3.csv')

# %%
#Merging three databases

# %%
final_df2=finaldata2[['Date', 'City' , 'State','Latitude','Longitude']]
final_df3=finaldata3[['Date', 'City' , 'State', 'Latitude','Longitude']]

# %%
final_df1.head()
# Out:
#          Date                      City       State   Latitude   Longitude
# 0  2009-01-27                Wilmington  California  33.783263 -118.254934
# 1  2009-02-14                 Brockport    New York  43.221000  -77.943000
# 2  2009-03-05                 Cleveland        Ohio  41.477464  -81.686514
# 3  2009-03-10  Coffee and Geneva County     Alabama  31.112900  -86.045900
# 4  2009-03-15                     Miami     Florida  25.737781  -80.259580

# %%
final_df2.head()
# Out:
#          Date         City      State   Latitude  Longitude
# 0  2022-11-12      Orlando    Florida  28.533346 -81.399993
# 1  2022-11-12  Minneapolis  Minnesota  45.041023 -93.286121
# 2  2022-11-12       Dothan    Alabama  31.225759 -85.402452
# 3  2022-11-12      Madison  Tennessee  36.248822 -86.719791
# 4  2022-11-12    Lexington   Kentucky  38.003982 -84.433147

# %%
final_df3.head()
# Out:
#          Date                    City                 State   Latitude  \
# 0  2022-11-10  Hyattsville (Landover)              Maryland  38.918969
# 1  2022-11-10                  Pueblo              Colorado  38.305986
# 2  2022-11-10              Washington  District of Columbia  38.856191
# 3  2022-11-09                  Boston         Massachusetts  42.292358
# 4  2022-11-09                  Oakton              Virginia  38.876570
#
#     Longitude
# 0  -76.882883
# 1 -104.606859
# 2  -76.986997
# 3  -71.090028
# 4  -77.339375

# %%
finaldatabase=pd.concat([final_df1,final_df2,final_df3],ignore_index = True)
finaldatabase
# Out:
#             Date                      City       State   Latitude   Longitude
# 0     2009-01-27                Wilmington  California  33.783263 -118.254934
# 1     2009-02-14                 Brockport    New York  43.221000  -77.943000
# 2     2009-03-05                 Cleveland        Ohio  41.477464  -81.686514
# 3     2009-03-10  Coffee and Geneva County     Alabama  31.112900  -86.045900
# 4     2009-03-15                     Miami     Florida  25.737781  -80.259580
# ...          ...                       ...         ...        ...         ...
# 4220  2022-09-26                Sacramento  California  38.618231 -121.466223
# 4221  2022-09-26                Sacramento  California  38.627766 -121.514173
# 4222  2022-09-26                   Memphis   Tennessee  35.054088  -89.996175
# 4223  2022-09-26               Kansas City    Missouri  39.079543  -94.520467
# 4224  2022-09-26                 Lafayette     Indiana  40.380370  -86.789487
#
# [4225 rows x 5 columns]

# %%
finaldatabase=finaldatabase.dropna(subset=["Latitude", "Longitude"])
finaldatabase= finaldatabase.drop_duplicates(subset=["Latitude", "Longitude"], keep='first')
finaldatabase
# Out:
#             Date                      City       State   Latitude   Longitude
# 0     2009-01-27                Wilmington  California  33.783263 -118.254934
# 1     2009-02-14                 Brockport    New York  43.221000  -77.943000
# 2     2009-03-05                 Cleveland        Ohio  41.477464  -81.686514
# 3     2009-03-10  Coffee and Geneva County     Alabama  31.112900  -86.045900
# 4     2009-03-15                     Miami     Florida  25.737781  -80.259580
# ...          ...                       ...         ...        ...         ...
# 4220  2022-09-26                Sacramento  California  38.618231 -121.466223
# 4221  2022-09-26                Sacramento  California  38.627766 -121.514173
# 4222  2022-09-26                   Memphis   Tennessee  35.054088  -89.996175
# 4223  2022-09-26               Kansas City    Missouri  39.079543  -94.520467
# 4224  2022-09-26                 Lafayette     Indiana  40.380370  -86.789487
#
# [2350 rows x 5 columns]

# %%
#Got the desired database and columns
finaldatabase.to_csv('finaldatabase.csv')

# %%
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  10000   30days      1000
# 1  PySpark  25000   40days      2300
# 2   Python  22000   35days      1200
# 3   pandas  30000   50days      2000
# 4   Python  22000   35days      1200
# 5    Spark  20000   30days      1000
# 6   pandas  30000   50days      2000

# %%
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  10000   30days      1000
# 1  PySpark  25000   40days      2300
# 2   Python  22000   35days      1200
# 3   pandas  30000   50days      2000
# 5    Spark  20000   30days      1000
